# %%
# !pip install torch torchvision torchaudio
# Out:
# Collecting torch
#   Downloading torch-2.11.0-cp310-cp310-win_amd64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\kuangqiqi\appdata\roaming\python\python310\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\users\kuangqiqi\.conda\envs\nndl\lib\site-packages (from torch) (80.10.2)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\kuangqiqi\.conda\envs\nndl\lib\site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in c:\users\kuangqiqi\appdata\roaming\python\python310\site-packages (from torchvision) (1.26.4)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-12.2.0-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kuangqiqi\appdata\roaming\python\python310\site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.11.0-cp310-cp310-win_amd64.whl (114.5 MB)
#    ---------------------------------------- 0.0/114.5 MB ? eta -:--:--
#    ---------------------------------------- 1.0/114.5 MB 49.2 MB/s eta 0:00:03
#    ---------------------------------------- 1.3/114.5 MB 6.7 MB/s eta 0:00:17
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.4/114.5 MB 5.2 MB/s eta 0:00:22
#     --------------------------------------- 2.6/114.5 MB 1.2 MB/s eta 0:01:30
#    - -------------------------------------- 3.7/114.5 MB 1.6 MB/s eta 0:01:10
#    -- ------------------------------------- 6.6/114.5 MB 2.6 MB/s eta 0:00:41
#    --- ------------------------------------ 10.7/114.5 MB 4.1 MB/s eta 0:00:26
#    --- ------------------------------------ 11.0/114.5 MB 4.0 MB/s eta 0:00:26
#    --- ------------------------------------ 11.3/114.5 MB 3.8 MB/s eta 0:00:28
#    ---- ----------------------------------- 11.5/114.5 MB 3.7 MB/s eta 0:00:28
#    ---- ----------------------------------- 11.5/114.5 MB 3.7 MB/s eta 0:00:28
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.1/114.5 MB 3.2 MB/s eta 0:00:32
#    ---- ----------------------------------- 12.3/114.5 MB 2.5 MB/s eta 0:00:42
#    ------ --------------------------------- 18.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------ --------------------------------- 19.9/114.5 MB 3.7 MB/s eta 0:00:26
#    ------- -------------------------------- 20.4/114.5 MB 3.1 MB/s eta 0:00:31
#    ------- -------------------------------- 21.2/114.5 MB 3.2 MB/s eta 0:00:30
#    ------- -------------------------------- 21.2/114.5 MB 3.2 MB/s eta 0:00:30
#    ------- -------------------------------- 21.2/114.5 MB 3.2 MB/s eta 0:00:30
#    ------- -------------------------------- 22.0/114.5 MB 2.9 MB/s eta 0:00:32
#    ------- -------------------------------- 22.5/114.5 MB 3.0 MB/s eta 0:00:32
#    -------- ------------------------------- 23.3/114.5 MB 3.0 MB/s eta 0:00:31
#    -------- ------------------------------- 23.3/114.5 MB 3.0 MB/s eta 0:00:31
#    -------- ------------------------------- 23.3/114.5 MB 3.0 MB/s eta 0:00:31
#    -------- ------------------------------- 23.6/114.5 MB 2.8 MB/s eta 0:00:33
#    -------- ------------------------------- 24.1/114.5 MB 2.8 MB/s eta 0:00:33
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 31.7/114.5 MB 3.6 MB/s eta 0:00:24
#    ----------- ---------------------------- 32.2/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.5/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
#    ----------- ---------------------------- 32.8/114.5 MB 3.2 MB/s eta 0:00:26
# Resuming download torch-2.11.0-cp310-cp310-win_amd64.whl (32.8 MB/114.5 MB)
#    ----------- ---------------------------- 32.8/114.5 MB ? eta -:--:--
#    ----------- ---------------------------- 33.0/114.5 MB ? eta -:--:--
#    ----------- ---------------------------- 33.0/114.5 MB ? eta -:--:--
#    ----------- ---------------------------- 33.0/114.5 MB ? eta -:--:--
#    ----------- ---------------------------- 33.0/114.5 MB ? eta -:--:--
#    ----------- --------------------------- 33.3/114.5 MB 559.5 kB/s eta 0:02:26
#    ----------- --------------------------- 33.8/114.5 MB 907.1 kB/s eta 0:01:29
#    ----------- ---------------------------- 34.3/114.5 MB 1.1 MB/s eta 0:01:11
#    ------------ --------------------------- 34.6/114.5 MB 1.2 MB/s eta 0:01:09
#    ------------ --------------------------- 34.9/114.5 MB 1.2 MB/s eta 0:01:05
#    ------------ --------------------------- 35.4/114.5 MB 1.3 MB/s eta 0:01:01
#    ------------ --------------------------- 35.4/114.5 MB 1.3 MB/s eta 0:01:01
#    ------------ --------------------------- 36.2/114.5 MB 1.4 MB/s eta 0:00:57
#    ------------ --------------------------- 37.0/114.5 MB 1.6 MB/s eta 0:00:50
#    ------------ --------------------------- 37.0/114.5 MB 1.6 MB/s eta 0:00:50
#    ------------ --------------------------- 37.0/114.5 MB 1.6 MB/s eta 0:00:50
#    ------------- -------------------------- 37.5/114.5 MB 1.4 MB/s eta 0:00:55
#    ------------- -------------------------- 38.0/114.5 MB 1.5 MB/s eta 0:00:51
#    ------------- -------------------------- 38.0/114.5 MB 1.5 MB/s eta 0:00:51
#    -------------- ------------------------- 42.7/114.5 MB 2.5 MB/s eta 0:00:29
#    -------------- ------------------------- 42.7/114.5 MB 2.5 MB/s eta 0:00:29
#    -------------- ------------------------- 42.7/114.5 MB 2.5 MB/s eta 0:00:29
#    --------------- ------------------------ 43.0/114.5 MB 2.2 MB/s eta 0:00:33
#    --------------- ------------------------ 43.8/114.5 MB 2.3 MB/s eta 0:00:31
#    ---------------- ----------------------- 47.7/114.5 MB 3.0 MB/s eta 0:00:23
#    ---------------- ----------------------- 47.7/114.5 MB 3.0 MB/s eta 0:00:23
#    ---------------- ----------------------- 48.0/114.5 MB 2.8 MB/s eta 0:00:24
#    ---------------- ----------------------- 48.5/114.5 MB 2.8 MB/s eta 0:00:24
#    ----------------- ---------------------- 49.8/114.5 MB 2.9 MB/s eta 0:00:23
#    ----------------- ---------------------- 49.8/114.5 MB 2.9 MB/s eta 0:00:23
#    ----------------- ---------------------- 49.8/114.5 MB 2.9 MB/s eta 0:00:23
#    ----------------- ---------------------- 50.3/114.5 MB 2.7 MB/s eta 0:00:24
#    ----------------- ---------------------- 50.6/114.5 MB 2.7 MB/s eta 0:00:24
#    ----------------- ---------------------- 51.1/114.5 MB 2.7 MB/s eta 0:00:24
#    ----------------- ---------------------- 51.4/114.5 MB 2.7 MB/s eta 0:00:24
#    ------------------ --------------------- 53.5/114.5 MB 2.9 MB/s eta 0:00:22
#    ------------------ --------------------- 54.0/114.5 MB 2.9 MB/s eta 0:00:21
#    ------------------ --------------------- 54.0/114.5 MB 2.9 MB/s eta 0:00:21
#    ------------------ --------------------- 54.0/114.5 MB 2.9 MB/s eta 0:00:21
#    ------------------ --------------------- 54.0/114.5 MB 2.9 MB/s eta 0:00:21
#    ------------------- -------------------- 54.8/114.5 MB 2.7 MB/s eta 0:00:23
#    ------------------- -------------------- 57.1/114.5 MB 2.9 MB/s eta 0:00:20
#    ------------------- -------------------- 57.1/114.5 MB 2.9 MB/s eta 0:00:20
#    -------------------- ------------------- 57.4/114.5 MB 2.8 MB/s eta 0:00:21
#    -------------------- ------------------- 58.2/114.5 MB 2.8 MB/s eta 0:00:21
#    -------------------- ------------------- 58.2/114.5 MB 2.8 MB/s eta 0:00:21
#    -------------------- ------------------- 58.2/114.5 MB 2.8 MB/s eta 0:00:21
#    -------------------- ------------------- 58.2/114.5 MB 2.8 MB/s eta 0:00:21
#    -------------------- ------------------- 58.5/114.5 MB 2.6 MB/s eta 0:00:22
#    -------------------- ------------------- 59.5/114.5 MB 2.6 MB/s eta 0:00:21
#    ---------------------- ----------------- 63.4/114.5 MB 3.0 MB/s eta 0:00:18
#    ---------------------- ----------------- 63.7/114.5 MB 2.9 MB/s eta 0:00:18
#    ---------------------- ----------------- 64.2/114.5 MB 2.9 MB/s eta 0:00:18
#    ----------------------- ---------------- 67.6/114.5 MB 3.2 MB/s eta 0:00:15
#    ----------------------- ---------------- 67.6/114.5 MB 3.2 MB/s eta 0:00:15
#    ----------------------- ---------------- 67.6/114.5 MB 3.2 MB/s eta 0:00:15
#    ----------------------- ---------------- 67.6/114.5 MB 3.2 MB/s eta 0:00:15
#    ----------------------- ---------------- 67.9/114.5 MB 3.0 MB/s eta 0:00:16
#    ----------------------- ---------------- 68.2/114.5 MB 3.0 MB/s eta 0:00:16
#    ------------------------ --------------- 69.2/114.5 MB 3.0 MB/s eta 0:00:16
#    ------------------------ --------------- 69.2/114.5 MB 3.0 MB/s eta 0:00:16
#    ------------------------ --------------- 69.2/114.5 MB 3.0 MB/s eta 0:00:16
#    ------------------------ --------------- 69.2/114.5 MB 3.0 MB/s eta 0:00:16
#    ------------------------ --------------- 69.7/114.5 MB 2.8 MB/s eta 0:00:16
#    ------------------------ --------------- 70.5/114.5 MB 2.8 MB/s eta 0:00:16
#    ------------------------- -------------- 72.9/114.5 MB 3.0 MB/s eta 0:00:14
#    ------------------------- -------------- 72.9/114.5 MB 3.0 MB/s eta 0:00:14
#    ------------------------- -------------- 72.9/114.5 MB 3.0 MB/s eta 0:00:14
#    ------------------------- -------------- 73.1/114.5 MB 2.9 MB/s eta 0:00:15
#    ------------------------- -------------- 73.9/114.5 MB 2.9 MB/s eta 0:00:15
#    -------------------------- ------------- 74.4/114.5 MB 2.9 MB/s eta 0:00:14
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.4/114.5 MB 3.2 MB/s eta 0:00:12
#    --------------------------- ------------ 79.7/114.5 MB 3.0 MB/s eta 0:00:12
#    ----------------------------- ---------- 83.6/114.5 MB 3.2 MB/s eta 0:00:10
#    ----------------------------- ---------- 83.6/114.5 MB 3.2 MB/s eta 0:00:10
#    ----------------------------- ---------- 84.1/114.5 MB 3.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 84.9/114.5 MB 3.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 85.7/114.5 MB 3.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 85.7/114.5 MB 3.1 MB/s eta 0:00:10
#    ----------------------------- ---------- 85.7/114.5 MB 3.1 MB/s eta 0:00:10
#    ------------------------------ --------- 86.0/114.5 MB 3.0 MB/s eta 0:00:10
#    ------------------------------ --------- 88.6/114.5 MB 3.1 MB/s eta 0:00:09
#    ------------------------------- -------- 89.1/114.5 MB 3.1 MB/s eta 0:00:09
#    ------------------------------- -------- 89.4/114.5 MB 3.1 MB/s eta 0:00:09
#    ------------------------------- -------- 90.2/114.5 MB 3.1 MB/s eta 0:00:08
#    ------------------------------- -------- 90.2/114.5 MB 3.1 MB/s eta 0:00:08
#    ------------------------------- -------- 90.2/114.5 MB 3.1 MB/s eta 0:00:08
#    ------------------------------- -------- 90.2/114.5 MB 3.1 MB/s eta 0:00:08
#    ------------------------------- -------- 90.4/114.5 MB 3.0 MB/s eta 0:00:09
#    ------------------------------- -------- 91.2/114.5 MB 3.0 MB/s eta 0:00:08
#    -------------------------------- ------- 91.8/114.5 MB 3.0 MB/s eta 0:00:08
#    -------------------------------- ------- 94.1/114.5 MB 3.1 MB/s eta 0:00:07
#    -------------------------------- ------- 94.1/114.5 MB 3.1 MB/s eta 0:00:07
#    -------------------------------- ------- 94.1/114.5 MB 3.1 MB/s eta 0:00:07
#    -------------------------------- ------- 94.4/114.5 MB 3.0 MB/s eta 0:00:07
#    -------------------------------- ------- 94.4/114.5 MB 3.0 MB/s eta 0:00:07
#    -------------------------------- ------- 94.4/114.5 MB 3.0 MB/s eta 0:00:07
#    -------------------------------- ------- 94.4/114.5 MB 3.0 MB/s eta 0:00:07
#    --------------------------------- ------ 94.9/114.5 MB 2.9 MB/s eta 0:00:07
#    ----------------------------------- ---- 102.5/114.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.8/114.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.8/114.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.8/114.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.8/114.5 MB 3.2 MB/s eta 0:00:04
#    ----------------------------------- ---- 102.8/114.5 MB 3.2 MB/s eta 0:00:04
#    ------------------------------------ --- 103.5/114.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 104.1/114.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 104.9/114.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 104.9/114.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 104.9/114.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------------ --- 105.4/114.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 106.2/114.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 106.7/114.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 107.5/114.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 107.5/114.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------------- -- 107.5/114.5 MB 3.1 MB/s eta 0:00:03
#    -------------------------------------- - 109.6/114.5 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------------- 114.5/114.5 MB 3.2 MB/s  0:00:25
# Downloading torchvision-0.26.0-cp310-cp310-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB ? eta -:--:--
#    -------------- ------------------------- 1.3/3.7 MB 4.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.1/3.7 MB 4.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 4.4 MB/s  0:00:00
# Downloading torchaudio-2.11.0-cp310-cp310-win_amd64.whl (328 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.4.2-py3-none-any.whl (1.7 MB)
# Downloading pillow-12.2.0-cp310-cp310-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.8/7.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/7.1 MB 9.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.8/7.1 MB 3.6 MB/s eta 0:00:02
#    -------------- ------------------------- 2.6/7.1 MB 3.6 MB/s eta 0:00:02
#    ------------------- -------------------- 3.4/7.1 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/7.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/7.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.0/7.1 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 5.5/7.1 MB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 3.5 MB/s  0:00:02
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Installing collected packages: torchaudio, mpmath, sympy, pillow, networkx, fsspec, filelock, torch, torchvision
#
#    ---------------------------------------- 0/9 [torchaudio]
#    ---------------------------------------- 0/9 [torchaudio]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    ---- ----------------------------------- 1/9 [mpmath]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    -------- ------------------------------- 2/9 [sympy]
#    ------------- -------------------------- 3/9 [pillow]
#    ------------- -------------------------- 3/9 [pillow]
#    ------------- -------------------------- 3/9 [pillow]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ----------------- ---------------------- 4/9 [networkx]
#    ---------------------- ----------------- 5/9 [fsspec]
#    -------------------------- ------------- 6/9 [filelock]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ------------------------------- -------- 7/9 [torch]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ----------------------------------- ---- 8/9 [torchvision]
#    ---------------------------------------- 9/9 [torchvision]
#
# Successfully installed filelock-3.25.2 fsspec-2026.3.0 mpmath-1.3.0 networkx-3.4.2 pillow-12.2.0 sympy-1.14.0 torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (32.8 MB/114.5 MB, attempt 1)

# %%
import os
import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.utils.data as Data
import torchvision
import torch.nn.functional as F
import numpy as np
learning_rate = 1e-4
keep_prob_rate = 0.7 #
max_epoch = 3
BATCH_SIZE = 50

DOWNLOAD_MNIST = False
if not(os.path.exists('./mnist/')) or not os.listdir('./mnist/'):
    # not mnist dir or mnist is empyt dir
    DOWNLOAD_MNIST = True


train_data = torchvision.datasets.MNIST(root='./mnist/',train=True, transform=torchvision.transforms.ToTensor(), download=DOWNLOAD_MNIST,)
train_loader = Data.DataLoader(dataset = train_data ,batch_size= BATCH_SIZE ,shuffle= True)

test_data = torchvision.datasets.MNIST(root = './mnist/',train = False)
test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
test_y = test_data.test_labels[:500].numpy()

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d( # ???
                # patch 7 * 7 ; 1  in channels ; 32 out channels ; ; stride is 1
                # padding style is same(that means the convolution opration's input and output have the same size)
                in_channels= 1     ,  
                out_channels= 32    ,
                kernel_size=  7    ,
                stride=  1         ,
                padding=  3        ,
            ),
            nn.ReLU(),        # activation function
            nn.MaxPool2d(2),  # pooling operation
        )
        self.conv2 = nn.Sequential( # ???
            # line 1 : convolution function, patch 5*5 , 32 in channels ;64 out channels; padding style is same; stride is 1
            # line 2 : choosing your activation funciont
            # line 3 : pooling operation function.
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),  # 32→64通道
            nn.ReLU(),
            nn.MaxPool2d(2),        # 再次池化，尺寸减半
        )
        self.out1 = nn.Linear( 7*7*64 , 1024 , bias= True)   # full connection layer one

        self.dropout = nn.Dropout(keep_prob_rate)
        self.out2 = nn.Linear(1024,10,bias=True)



    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(x.size(0), -1)  # flatten the output of coonv2 to (batch_size ,32 * 7 * 7)    # ???
        out1 = self.out1(x)
        out1 = F.relu(out1)
        out1 = self.dropout(out1)
        out2 = self.out2(out1)
        output = F.softmax(out2,dim=-1)
        return output


def test(cnn):
    global prediction
    y_pre = cnn(test_x)
    _,pre_index= torch.max(y_pre,1)
    pre_index= pre_index.view(-1)
    prediction = pre_index.data.numpy()
    correct  = np.sum(prediction == test_y)
    return correct / 500.0


def train(cnn):
    optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate )
    loss_func = nn.CrossEntropyLoss()
    for epoch in range(max_epoch):
        for step, (x_, y_) in enumerate(train_loader):
            x ,y= Variable(x_),Variable(y_)
            output = cnn(x)  
            loss = loss_func(output,y)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
            if step != 0 and step % 20 ==0:
                print("=" * 10,step,"="*5,"="*5, "test accuracy is ",test(cnn) ,"=" * 10 )

if __name__ == '__main__':
    cnn = CNN()
    train(cnn)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:03<00:00, 2.72MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 136kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:01<00:00, 1.05MB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 2.03MB/s]
# C:\Users\kuangqiqi\.conda\envs\nndl\lib\site-packages\torchvision\datasets\mnist.py:81: UserWarning: test_data has been renamed data
#   warnings.warn("test_data has been renamed data")
# C:\Users\kuangqiqi\AppData\Local\Temp\ipykernel_23804\2363578544.py:24: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   test_x = Variable(torch.unsqueeze(test_data.test_data,dim  = 1),volatile = True).type(torch.FloatTensor)[:500]/255.
# C:\Users\kuangqiqi\.conda\envs\nndl\lib\site-packages\torchvision\datasets\mnist.py:71: UserWarning: test_labels has been renamed targets
#   warnings.warn("test_labels has been renamed targets")
# ========== 20 ===== ===== test accuracy is  0.288 ==========
# ========== 40 ===== ===== test accuracy is  0.318 ==========
# ========== 60 ===== ===== test accuracy is  0.432 ==========
# ========== 80 ===== ===== test accuracy is  0.514 ==========
# ========== 100 ===== ===== test accuracy is  0.598 ==========
# ========== 120 ===== ===== test accuracy is  0.626 ==========
# ========== 140 ===== ===== test accuracy is  0.646 ==========
# ========== 160 ===== ===== test accuracy is  0.696 ==========
# ========== 180 ===== ===== test accuracy is  0.744 ==========
# ========== 200 ===== ===== test accuracy is  0.77 ==========
# ========== 220 ===== ===== test accuracy is  0.782 ==========
# ========== 240 ===== ===== test accuracy is  0.808 ==========
# ========== 260 ===== ===== test accuracy is  0.824 ==========
# ========== 280 ===== ===== test accuracy is  0.844 ==========
# ========== 300 ===== ===== test accuracy is  0.868 ==========
# ========== 320 ===== ===== test accuracy is  0.854 ==========
# ========== 340 ===== ===== test accuracy is  0.852 ==========
# ========== 360 ===== ===== test accuracy is  0.868 ==========
# ========== 380 ===== ===== test accuracy is  0.868 ==========
# ========== 400 ===== ===== test accuracy is  0.866 ==========
# ========== 420 ===== ===== test accuracy is  0.87 ==========
# ========== 440 ===== ===== test accuracy is  0.884 ==========
# ========== 460 ===== ===== test accuracy is  0.888 ==========
# ========== 480 ===== ===== test accuracy is  0.896 ==========
# ========== 500 ===== ===== test accuracy is  0.902 ==========
# ========== 520 ===== ===== test accuracy is  0.878 ==========
# ========== 540 ===== ===== test accuracy is  0.904 ==========
# ========== 560 ===== ===== test accuracy is  0.932 ==========
# ========== 580 ===== ===== test accuracy is  0.896 ==========
# ========== 600 ===== ===== test accuracy is  0.902 ==========
# ========== 620 ===== ===== test accuracy is  0.916 ==========
# ========== 640 ===== ===== test accuracy is  0.926 ==========
# ========== 660 ===== ===== test accuracy is  0.906 ==========
# ========== 680 ===== ===== test accuracy is  0.926 ==========
# ========== 700 ===== ===== test accuracy is  0.918 ==========
# ========== 720 ===== ===== test accuracy is  0.924 ==========
# ========== 740 ===== ===== test accuracy is  0.928 ==========
# ========== 760 ===== ===== test accuracy is  0.926 ==========
# ========== 780 ===== ===== test accuracy is  0.928 ==========
# ========== 800 ===== ===== test accuracy is  0.93 ==========
# ========== 820 ===== ===== test accuracy is  0.924 ==========
# ========== 840 ===== ===== test accuracy is  0.942 ==========
# ========== 860 ===== ===== test accuracy is  0.936 ==========
# ========== 880 ===== ===== test accuracy is  0.934 ==========
# ========== 900 ===== ===== test accuracy is  0.936 ==========
# ========== 920 ===== ===== test accuracy is  0.934 ==========
# ========== 940 ===== ===== test accuracy is  0.948 ==========
# ========== 960 ===== ===== test accuracy is  0.942 ==========
# ========== 980 ===== ===== test accuracy is  0.948 ==========
# ========== 1000 ===== ===== test accuracy is  0.94 ==========
# ========== 1020 ===== ===== test accuracy is  0.94 ==========
# ========== 1040 ===== ===== test accuracy is  0.938 ==========
# ========== 1060 ===== ===== test accuracy is  0.94 ==========
# ========== 1080 ===== ===== test accuracy is  0.944 ==========
# ========== 1100 ===== ===== test accuracy is  0.96 ==========
# ========== 1120 ===== ===== test accuracy is  0.95 ==========
# ========== 1140 ===== ===== test accuracy is  0.944 ==========
# ========== 1160 ===== ===== test accuracy is  0.948 ==========
# ========== 1180 ===== ===== test accuracy is  0.952 ==========
# ========== 20 ===== ===== test accuracy is  0.942 ==========
# ========== 40 ===== ===== test accuracy is  0.95 ==========
# ========== 60 ===== ===== test accuracy is  0.946 ==========
# ========== 80 ===== ===== test accuracy is  0.95 ==========
# ========== 100 ===== ===== test accuracy is  0.94 ==========
# ========== 120 ===== ===== test accuracy is  0.962 ==========
# ========== 140 ===== ===== test accuracy is  0.962 ==========
# ========== 160 ===== ===== test accuracy is  0.954 ==========
# ========== 180 ===== ===== test accuracy is  0.952 ==========
# ========== 200 ===== ===== test accuracy is  0.952 ==========
# ========== 220 ===== ===== test accuracy is  0.956 ==========
# ========== 240 ===== ===== test accuracy is  0.942 ==========
# ========== 260 ===== ===== test accuracy is  0.94 ==========
# ========== 280 ===== ===== test accuracy is  0.954 ==========
# ========== 300 ===== ===== test accuracy is  0.952 ==========
# ========== 320 ===== ===== test accuracy is  0.958 ==========
# ========== 340 ===== ===== test accuracy is  0.952 ==========
# ========== 360 ===== ===== test accuracy is  0.96 ==========
# ========== 380 ===== ===== test accuracy is  0.958 ==========
# ========== 400 ===== ===== test accuracy is  0.956 ==========
# ========== 420 ===== ===== test accuracy is  0.962 ==========
# ========== 440 ===== ===== test accuracy is  0.954 ==========
# ========== 460 ===== ===== test accuracy is  0.956 ==========
# ========== 480 ===== ===== test accuracy is  0.962 ==========
# ========== 500 ===== ===== test accuracy is  0.954 ==========
# ========== 520 ===== ===== test accuracy is  0.962 ==========
# ========== 540 ===== ===== test accuracy is  0.958 ==========
# ========== 560 ===== ===== test accuracy is  0.966 ==========
# ========== 580 ===== ===== test accuracy is  0.966 ==========
# ========== 600 ===== ===== test accuracy is  0.954 ==========
# ========== 620 ===== ===== test accuracy is  0.966 ==========
# ========== 640 ===== ===== test accuracy is  0.97 ==========
# ========== 660 ===== ===== test accuracy is  0.97 ==========
# ========== 680 ===== ===== test accuracy is  0.948 ==========
# ========== 700 ===== ===== test accuracy is  0.948 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.962 ==========
# ========== 760 ===== ===== test accuracy is  0.956 ==========
# ========== 780 ===== ===== test accuracy is  0.966 ==========
# ========== 800 ===== ===== test accuracy is  0.954 ==========
# ========== 820 ===== ===== test accuracy is  0.966 ==========
# ========== 840 ===== ===== test accuracy is  0.958 ==========
# ========== 860 ===== ===== test accuracy is  0.97 ==========
# ========== 880 ===== ===== test accuracy is  0.964 ==========
# ========== 900 ===== ===== test accuracy is  0.97 ==========
# ========== 920 ===== ===== test accuracy is  0.976 ==========
# ========== 940 ===== ===== test accuracy is  0.97 ==========
# ========== 960 ===== ===== test accuracy is  0.966 ==========
# ========== 980 ===== ===== test accuracy is  0.956 ==========
# ========== 1000 ===== ===== test accuracy is  0.972 ==========
# ========== 1020 ===== ===== test accuracy is  0.972 ==========
# ========== 1040 ===== ===== test accuracy is  0.968 ==========
# ========== 1060 ===== ===== test accuracy is  0.958 ==========
# ========== 1080 ===== ===== test accuracy is  0.976 ==========
# ========== 1100 ===== ===== test accuracy is  0.976 ==========
# ========== 1120 ===== ===== test accuracy is  0.966 ==========
# ========== 1140 ===== ===== test accuracy is  0.964 ==========
# ========== 1160 ===== ===== test accuracy is  0.964 ==========
# ========== 1180 ===== ===== test accuracy is  0.966 ==========
# ========== 20 ===== ===== test accuracy is  0.964 ==========
# ========== 40 ===== ===== test accuracy is  0.976 ==========
# ========== 60 ===== ===== test accuracy is  0.972 ==========
# ========== 80 ===== ===== test accuracy is  0.968 ==========
# ========== 100 ===== ===== test accuracy is  0.972 ==========
# ========== 120 ===== ===== test accuracy is  0.976 ==========
# ========== 140 ===== ===== test accuracy is  0.97 ==========
# ========== 160 ===== ===== test accuracy is  0.976 ==========
# ========== 180 ===== ===== test accuracy is  0.966 ==========
# ========== 200 ===== ===== test accuracy is  0.972 ==========
# ========== 220 ===== ===== test accuracy is  0.97 ==========
# ========== 240 ===== ===== test accuracy is  0.968 ==========
# ========== 260 ===== ===== test accuracy is  0.968 ==========
# ========== 280 ===== ===== test accuracy is  0.97 ==========
# ========== 300 ===== ===== test accuracy is  0.974 ==========
# ========== 320 ===== ===== test accuracy is  0.972 ==========
# ========== 340 ===== ===== test accuracy is  0.972 ==========
# ========== 360 ===== ===== test accuracy is  0.97 ==========
# ========== 380 ===== ===== test accuracy is  0.976 ==========
# ========== 400 ===== ===== test accuracy is  0.972 ==========
# ========== 420 ===== ===== test accuracy is  0.98 ==========
# ========== 440 ===== ===== test accuracy is  0.974 ==========
# ========== 460 ===== ===== test accuracy is  0.97 ==========
# ========== 480 ===== ===== test accuracy is  0.972 ==========
# ========== 500 ===== ===== test accuracy is  0.97 ==========
# ========== 520 ===== ===== test accuracy is  0.97 ==========
# ========== 540 ===== ===== test accuracy is  0.98 ==========
# ========== 560 ===== ===== test accuracy is  0.978 ==========
# ========== 580 ===== ===== test accuracy is  0.974 ==========
# ========== 600 ===== ===== test accuracy is  0.972 ==========
# ========== 620 ===== ===== test accuracy is  0.97 ==========
# ========== 640 ===== ===== test accuracy is  0.974 ==========
# ========== 660 ===== ===== test accuracy is  0.978 ==========
# ========== 680 ===== ===== test accuracy is  0.974 ==========
# ========== 700 ===== ===== test accuracy is  0.97 ==========
# ========== 720 ===== ===== test accuracy is  0.962 ==========
# ========== 740 ===== ===== test accuracy is  0.976 ==========
# ========== 760 ===== ===== test accuracy is  0.976 ==========
# ========== 780 ===== ===== test accuracy is  0.972 ==========
# ========== 800 ===== ===== test accuracy is  0.972 ==========
# ========== 820 ===== ===== test accuracy is  0.976 ==========
# ========== 840 ===== ===== test accuracy is  0.984 ==========
# ========== 860 ===== ===== test accuracy is  0.98 ==========
# ========== 880 ===== ===== test accuracy is  0.986 ==========
# ========== 900 ===== ===== test accuracy is  0.976 ==========
# ========== 920 ===== ===== test accuracy is  0.974 ==========
# ========== 940 ===== ===== test accuracy is  0.976 ==========
# ========== 960 ===== ===== test accuracy is  0.972 ==========
# ========== 980 ===== ===== test accuracy is  0.968 ==========
# ========== 1000 ===== ===== test accuracy is  0.976 ==========
# ========== 1020 ===== ===== test accuracy is  0.982 ==========
# ========== 1040 ===== ===== test accuracy is  0.976 ==========
# ========== 1060 ===== ===== test accuracy is  0.974 ==========
# ========== 1080 ===== ===== test accuracy is  0.98 ==========
# ========== 1100 ===== ===== test accuracy is  0.97 ==========
# ========== 1120 ===== ===== test accuracy is  0.978 ==========
# ========== 1140 ===== ===== test accuracy is  0.974 ==========
# ========== 1160 ===== ===== test accuracy is  0.976 ==========
# ========== 1180 ===== ===== test accuracy is  0.978 ==========
